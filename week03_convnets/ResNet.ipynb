# %%
import numpy as np
from torchvision.datasets import CIFAR10
from torch.utils.tensorboard import SummaryWriter
import torchvision
from torchvision import transforms
import torch, torch.nn as nn
import torch.nn.functional as F

# %%
means = np.array((0.4914, 0.4822, 0.4465))
stds = np.array((0.2023, 0.1994, 0.2010))

transform_augment = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomRotation([-30, 30]),
    transforms.RandomAffine(0, shear=10, scale=(0.8,1.2)), #Performs actions like zooms, change shear angles.
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2), # Set the color params
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(means, stds),
])


transform_augment_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(means, stds)])

batch_size = 400


train_loader = CIFAR10("./cifar_data/", train=True, transform=transform_augment)
trainloader = torch.utils.data.DataLoader(train_loader, 
                                          batch_size=batch_size,
                                          shuffle=True, 
                                          num_workers=2)


test_loader = CIFAR10("./cifar_data/", train=False, transform=transform_augment_test)
testloader = torch.utils.data.DataLoader(test_loader, 
                                         batch_size=batch_size,
                                         shuffle=False, 
                                         num_workers=2)

# %%
import sys
 
# setting path
sys.path.append('../')
from models import train_model

# %%
def conv_block(in_channels, out_channels, pool=False):
    layers = [nn.Conv2d(in_channels, out_channels, kernel_size=3, padding=1), 
              nn.BatchNorm2d(out_channels), 
              nn.ReLU(inplace=True)]
    if pool: layers.append(nn.MaxPool2d(2))
    return nn.Sequential(*layers)

class ResNet9(nn.Module):
    def __init__(self, in_channels, num_classes):
        super().__init__()
        
        self.conv1 = conv_block(in_channels, 64)
        self.conv2 = conv_block(64, 128, pool=True)
        self.res1 = nn.Sequential(conv_block(128, 128), conv_block(128, 128))
        
        self.conv3 = conv_block(128, 256, pool=True)
        self.conv4 = conv_block(256, 512, pool=True)
        self.res2 = nn.Sequential(conv_block(512, 512), conv_block(512, 512))
        
        self.classifier = nn.Sequential(nn.MaxPool2d(4), 
                                        nn.Flatten(), 
                                        nn.Linear(512, num_classes))
        
    def forward(self, xb):
        out = self.conv1(xb)
        out = self.conv2(out)
        out = self.res1(out) + out
        out = self.conv3(out)
        out = self.conv4(out)
        out = self.res2(out) + out
        out = self.classifier(out)
        return out

# %%
device = ("cuda" if torch.cuda.is_available() else 'cpu')
model = ResNet9(3, 10).to(device)

weight_decay = 1e-4

optimizer = torch.optim.Adam(model.parameters(), lr= 0.001) # 0.001 !
# optimizer = torch.optim.Adam(model.parameters(), lr= 0.001, weight_decay=weight_decay) # 0.001 !
criterion = torch.nn.CrossEntropyLoss()

tb = SummaryWriter()
model, optimizer = train_model(model, criterion, 
                    optimizer, train_dataloader=trainloader, test_dataloader=testloader, 
                    device=device,
                    n_epochs=100, batch_size=batch_size)
# Out:
# INFO Epoch 0
# INFO The mean accuracy train: 0.388
# INFO The mean accuracy test: 0.538
# INFO -------------------------------
# INFO Epoch 1
# INFO The mean accuracy train: 0.553
# INFO The mean accuracy test: 0.640
# INFO -------------------------------
# INFO Epoch 2
# INFO The mean accuracy train: 0.631
# INFO The mean accuracy test: 0.679
# INFO -------------------------------
# INFO Epoch 3
# INFO The mean accuracy train: 0.676
# INFO The mean accuracy test: 0.700
# INFO -------------------------------
# INFO Epoch 4
# INFO The mean accuracy train: 0.707
# INFO The mean accuracy test: 0.724
# INFO -------------------------------
# INFO Epoch 5
# INFO The mean accuracy train: 0.727
# INFO The mean accuracy test: 0.755
# INFO -------------------------------
# INFO Epoch 6
# INFO The mean accuracy train: 0.741
# INFO The mean accuracy test: 0.781
# INFO -------------------------------
# INFO Epoch 7
# INFO The mean accuracy train: 0.759
# INFO The mean accuracy test: 0.787
# INFO -------------------------------
# INFO Epoch 8
# INFO The mean accuracy train: 0.774
# INFO The mean accuracy test: 0.782
# INFO -------------------------------
# INFO Epoch 9
# INFO The mean accuracy train: 0.784
# INFO The mean accuracy test: 0.788
# INFO -------------------------------
# INFO Epoch 10
# INFO The mean accuracy train: 0.793
# INFO The mean accuracy test: 0.786
# INFO -------------------------------
# INFO Epoch 11
# INFO The mean accuracy train: 0.801
# INFO The mean accuracy test: 0.828
# INFO -------------------------------
# INFO Epoch 12
# INFO The mean accuracy train: 0.811
# INFO The mean accuracy test: 0.815
# INFO -------------------------------
# INFO Epoch 13
# INFO The mean accuracy train: 0.819
# INFO The mean accuracy test: 0.830
# INFO -------------------------------
# INFO Epoch 14
# INFO The mean accuracy train: 0.826
# INFO The mean accuracy test: 0.834
# INFO -------------------------------
# INFO Epoch 15
# INFO The mean accuracy train: 0.832
# INFO The mean accuracy test: 0.843
# INFO -------------------------------
# INFO Epoch 16
# INFO The mean accuracy train: 0.838
# INFO The mean accuracy test: 0.836
# INFO -------------------------------
# INFO Epoch 17
# INFO The mean accuracy train: 0.843
# INFO The mean accuracy test: 0.843
# INFO -------------------------------
# INFO Epoch 18
# INFO The mean accuracy train: 0.849
# INFO The mean accuracy test: 0.839
# INFO -------------------------------
# INFO Epoch 19
# INFO The mean accuracy train: 0.852
# INFO The mean accuracy test: 0.830
# INFO -------------------------------
# INFO Epoch 20
# INFO The mean accuracy train: 0.855
# INFO The mean accuracy test: 0.840
# INFO -------------------------------
# INFO Epoch 21
# INFO The mean accuracy train: 0.856
# INFO The mean accuracy test: 0.842
# INFO -------------------------------
# INFO Epoch 22
# INFO The mean accuracy train: 0.864
# INFO The mean accuracy test: 0.849
# INFO -------------------------------
# INFO Epoch 23
# INFO The mean accuracy train: 0.868
# INFO The mean accuracy test: 0.857
# INFO -------------------------------
# INFO Epoch 24
# INFO The mean accuracy train: 0.872
# INFO The mean accuracy test: 0.858
# INFO -------------------------------
# INFO Epoch 25
# INFO The mean accuracy train: 0.874
# INFO The mean accuracy test: 0.854
# INFO -------------------------------
# INFO Epoch 26
# INFO The mean accuracy train: 0.878
# INFO The mean accuracy test: 0.859
# INFO -------------------------------
# INFO Epoch 27
# INFO The mean accuracy train: 0.882
# INFO The mean accuracy test: 0.864
# INFO -------------------------------
# INFO Epoch 28
# INFO The mean accuracy train: 0.883
# INFO The mean accuracy test: 0.857
# INFO -------------------------------
# INFO Epoch 29
# INFO The mean accuracy train: 0.887
# INFO The mean accuracy test: 0.863
# INFO -------------------------------
# INFO Epoch 30
# INFO The mean accuracy train: 0.889
# INFO The mean accuracy test: 0.869
# INFO -------------------------------
# INFO Epoch 31
# INFO The mean accuracy train: 0.890
# INFO The mean accuracy test: 0.851
# INFO -------------------------------
# INFO Epoch 32
# INFO The mean accuracy train: 0.895
# INFO The mean accuracy test: 0.855
# INFO -------------------------------
# INFO Epoch 33
# INFO The mean accuracy train: 0.898
# INFO The mean accuracy test: 0.868
# INFO -------------------------------
# INFO Epoch 34
# INFO The mean accuracy train: 0.899
# INFO The mean accuracy test: 0.866
# INFO -------------------------------
# INFO Epoch 35
# INFO The mean accuracy train: 0.900
# INFO The mean accuracy test: 0.863
# INFO -------------------------------
# INFO Epoch 36
# INFO The mean accuracy train: 0.904
# INFO The mean accuracy test: 0.864
# INFO -------------------------------
# INFO Epoch 37
# INFO The mean accuracy train: 0.904
# INFO The mean accuracy test: 0.865
# INFO -------------------------------
# INFO Epoch 38
# INFO The mean accuracy train: 0.906
# INFO The mean accuracy test: 0.866
# INFO -------------------------------
# INFO Epoch 39
# INFO The mean accuracy train: 0.909
# INFO The mean accuracy test: 0.872
# INFO -------------------------------
# INFO Epoch 40
# INFO The mean accuracy train: 0.912
# INFO The mean accuracy test: 0.871
# INFO -------------------------------
# INFO Epoch 41
# INFO The mean accuracy train: 0.914
# INFO The mean accuracy test: 0.869
# INFO -------------------------------
# INFO Epoch 42
# INFO The mean accuracy train: 0.913
# INFO The mean accuracy test: 0.865
# INFO -------------------------------
# INFO Epoch 43
# INFO The mean accuracy train: 0.915
# INFO The mean accuracy test: 0.873
# INFO -------------------------------
# INFO Epoch 44
# INFO The mean accuracy train: 0.920
# INFO The mean accuracy test: 0.873
# INFO -------------------------------
# INFO Epoch 45
# INFO The mean accuracy train: 0.917
# INFO The mean accuracy test: 0.874
# INFO -------------------------------
# INFO Epoch 46
# INFO The mean accuracy train: 0.923
# INFO The mean accuracy test: 0.871
# INFO -------------------------------
# INFO Epoch 47
# INFO The mean accuracy train: 0.925
# INFO The mean accuracy test: 0.877
# INFO -------------------------------
# INFO Epoch 48
# INFO The mean accuracy train: 0.927
# INFO The mean accuracy test: 0.872
# INFO -------------------------------
# INFO Epoch 49
# INFO The mean accuracy train: 0.926
# INFO The mean accuracy test: 0.863
# INFO -------------------------------
# INFO Epoch 50
# INFO The mean accuracy train: 0.927
# INFO The mean accuracy test: 0.877
# INFO -------------------------------
# INFO Epoch 51
# INFO The mean accuracy train: 0.929
# INFO The mean accuracy test: 0.878
# INFO -------------------------------
# INFO Epoch 52
# INFO The mean accuracy train: 0.929
# INFO The mean accuracy test: 0.882
# INFO -------------------------------
# INFO Epoch 53
# INFO The mean accuracy train: 0.932
# INFO The mean accuracy test: 0.875
# INFO -------------------------------
# INFO Epoch 54
# INFO The mean accuracy train: 0.932
# INFO The mean accuracy test: 0.871
# INFO -------------------------------
# INFO Epoch 55
# INFO The mean accuracy train: 0.936
# INFO The mean accuracy test: 0.885
# INFO -------------------------------
# INFO Epoch 56
# INFO The mean accuracy train: 0.936
# INFO The mean accuracy test: 0.870
# INFO -------------------------------
# INFO Epoch 57
# INFO The mean accuracy train: 0.936
# INFO The mean accuracy test: 0.873
# INFO -------------------------------
# INFO Epoch 58
# INFO The mean accuracy train: 0.937
# INFO The mean accuracy test: 0.880
# INFO -------------------------------
# INFO Epoch 59
# INFO The mean accuracy train: 0.939
# INFO The mean accuracy test: 0.873
# INFO -------------------------------
# INFO Epoch 60
# INFO The mean accuracy train: 0.942
# INFO The mean accuracy test: 0.877
# INFO -------------------------------
# INFO Epoch 61
# INFO The mean accuracy train: 0.942
# INFO The mean accuracy test: 0.868
# INFO -------------------------------
# INFO Epoch 62
# INFO The mean accuracy train: 0.942
# INFO The mean accuracy test: 0.877
# INFO -------------------------------
# INFO Epoch 63
# INFO The mean accuracy train: 0.944
# INFO The mean accuracy test: 0.866
# INFO -------------------------------
# INFO Epoch 64
# INFO The mean accuracy train: 0.944
# INFO The mean accuracy test: 0.867
# INFO -------------------------------
# INFO Epoch 65
# INFO The mean accuracy train: 0.945
# INFO The mean accuracy test: 0.879
# INFO -------------------------------
# INFO Epoch 66
# INFO The mean accuracy train: 0.946
# INFO The mean accuracy test: 0.882
# INFO -------------------------------
# INFO Epoch 67
# INFO The mean accuracy train: 0.945
# INFO The mean accuracy test: 0.884
# INFO -------------------------------
# INFO Epoch 68
# INFO The mean accuracy train: 0.947
# INFO The mean accuracy test: 0.868
# INFO -------------------------------
# INFO Epoch 69
# INFO The mean accuracy train: 0.946
# INFO The mean accuracy test: 0.875
# INFO -------------------------------
# INFO Epoch 70
# INFO The mean accuracy train: 0.948
# INFO The mean accuracy test: 0.878
# INFO -------------------------------
# INFO Epoch 71
# INFO The mean accuracy train: 0.949
# INFO The mean accuracy test: 0.881
# INFO -------------------------------
# INFO Epoch 72
# INFO The mean accuracy train: 0.952
# INFO The mean accuracy test: 0.880
# INFO -------------------------------
# INFO Epoch 73
# INFO The mean accuracy train: 0.952
# INFO The mean accuracy test: 0.867
# INFO -------------------------------
# INFO Epoch 74
# INFO The mean accuracy train: 0.951
# INFO The mean accuracy test: 0.886
# INFO -------------------------------
# INFO Epoch 75
# INFO The mean accuracy train: 0.951
# INFO The mean accuracy test: 0.884
# INFO -------------------------------
# INFO Epoch 76
# INFO The mean accuracy train: 0.951
# INFO The mean accuracy test: 0.886
# INFO -------------------------------
# INFO Epoch 77
# INFO The mean accuracy train: 0.955
# INFO The mean accuracy test: 0.885
# INFO -------------------------------
# INFO Epoch 78
# INFO The mean accuracy train: 0.956
# INFO The mean accuracy test: 0.884
# INFO -------------------------------
# INFO Epoch 79
# INFO The mean accuracy train: 0.957
# INFO The mean accuracy test: 0.881
# INFO -------------------------------
# INFO Epoch 80
# INFO The mean accuracy train: 0.955
# INFO The mean accuracy test: 0.868
# INFO -------------------------------
# INFO Epoch 81
# INFO The mean accuracy train: 0.955
# INFO The mean accuracy test: 0.874
# INFO -------------------------------
# INFO Epoch 82
# INFO The mean accuracy train: 0.957
# INFO The mean accuracy test: 0.879
# INFO -------------------------------
# INFO Epoch 83
# INFO The mean accuracy train: 0.956
# INFO The mean accuracy test: 0.871
# INFO -------------------------------
# INFO Epoch 84
# INFO The mean accuracy train: 0.958
# INFO The mean accuracy test: 0.877
# INFO -------------------------------
# INFO Epoch 85
# INFO The mean accuracy train: 0.960
# INFO The mean accuracy test: 0.877
# INFO -------------------------------
# INFO Epoch 86
# INFO The mean accuracy train: 0.960
# INFO The mean accuracy test: 0.880
# INFO -------------------------------
# INFO Epoch 87
# INFO The mean accuracy train: 0.958
# INFO The mean accuracy test: 0.879
# INFO -------------------------------
# INFO Epoch 88
# INFO The mean accuracy train: 0.960
# INFO The mean accuracy test: 0.871
# INFO -------------------------------
# INFO Epoch 89
# INFO The mean accuracy train: 0.958
# INFO The mean accuracy test: 0.883
# INFO -------------------------------
# INFO Epoch 90
# INFO The mean accuracy train: 0.962
# INFO The mean accuracy test: 0.871
# INFO -------------------------------
# INFO Epoch 91
# INFO The mean accuracy train: 0.961
# INFO The mean accuracy test: 0.881
# INFO -------------------------------
# INFO Epoch 92
# INFO The mean accuracy train: 0.963
# INFO The mean accuracy test: 0.886
# INFO -------------------------------
# INFO Epoch 93
# INFO The mean accuracy train: 0.963
# INFO The mean accuracy test: 0.874
# INFO -------------------------------
# INFO Epoch 94
# INFO The mean accuracy train: 0.963
# INFO The mean accuracy test: 0.873
# INFO -------------------------------
# INFO Epoch 95
# INFO The mean accuracy train: 0.964
# INFO The mean accuracy test: 0.877
# INFO -------------------------------
# INFO Epoch 96
# INFO The mean accuracy train: 0.964
# INFO The mean accuracy test: 0.868
# INFO -------------------------------
# INFO Epoch 97
# INFO The mean accuracy train: 0.965
# INFO The mean accuracy test: 0.881
# INFO -------------------------------
# INFO Epoch 98
# INFO The mean accuracy train: 0.965
# INFO The mean accuracy test: 0.878
# INFO -------------------------------
# INFO Epoch 99
# INFO The mean accuracy train: 0.963
# INFO The mean accuracy test: 0.882
# INFO -------------------------------

# %%
correct = 0
total = 0
# since we're not training, we don't need to calculate the gradients for our outputs
with torch.no_grad():
    for data in testloader:
        images, labels = data
        images = images.to(device)
        labels = labels.to(device)
        # calculate outputs by running images through the network
        outputs = model(images)
        # the class with the highest energy is what we choose as prediction
        _, predicted = torch.max(outputs.data, 1)
        total += labels.size(0)
        correct += (predicted == labels).sum().item()

print(f'Accuracy of test images: {100 * correct // total} %')
# Out:
# Exception ignored in: <function _MultiProcessingDataLoaderIter.__del__ at 0x7f981c7ccb80>
# Traceback (most recent call last):
#   File "/home/work/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1466, in __del__
#     self._shutdown_workers()
#   File "/home/work/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1449, in _shutdown_workers
#     if w.is_alive():Exception ignored in:
# <function _MultiProcessingDataLoaderIter.__del__ at 0x7f981c7ccb80>  File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#
# Traceback (most recent call last):
#   File "/home/work/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1466, in __del__
#         self._shutdown_workers()
# assert self._parent_pid == os.getpid(), 'can only test a child process'
#   File "/home/work/.local/lib/python3.8/site-packages/torch/utils/data/dataloader.py", line 1449, in _shutdown_workers
# AssertionError    : can only test a child processif w.is_alive():
#
#   File "/usr/lib/python3.8/multiprocessing/process.py", line 160, in is_alive
#     assert self._parent_pid == os.getpid(), 'can only test a child process'
# AssertionError: can only test a child process
# Accuracy of test images: 86 %

# %%
checkpoint = {
    'model': model.state_dict(),
    'optimizer': optimizer.state_dict()}
torch.save(checkpoint, 'resnet.pth')
